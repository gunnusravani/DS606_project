# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 40.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 27.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
df = pd.read_csv("jailbreak.csv")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1668 entries, 0 to 1667
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   num                      1668 non-null   int64
#  1   English                  1668 non-null   str
#  2   category                 1668 non-null   str
#  3   sub_category             1668 non-null   str
#  4   assamese                 1668 non-null   str
#  5   telugu                   1668 non-null   str
#  6   marathi                  1668 non-null   str
#  7   hindi                    1668 non-null   str
#  8   bengali                  1668 non-null   str
#  9   malicious_words_telugu   1668 non-null   str
#  10  malicious_words_marathi  1668 non-null   str
#  11  malicious_words_hindi    1668 non-null   str
#  12  malicious_words_bengali  1668 non-null   str
#  13  malicious_words_English  1668 non-null   str
#  14  hindi_prompt             1668 non-null   str
# ...

# %%
df.columns
# Out:
# Index(['num', 'English', 'category', 'sub_category', 'assamese', 'telugu',
#        'marathi', 'hindi', 'bengali', 'malicious_words_telugu',
#        'malicious_words_marathi', 'malicious_words_hindi',
#        'malicious_words_bengali', 'malicious_words_English', 'hindi_prompt',
#        'telugu_prompt', 'marathi_prompt', 'bengali_prompt', 'English_prompt'],
#       dtype='str')

# %%
# drop the columns
df = df.drop(columns=['malicious_words_telugu',
       'malicious_words_marathi', 'malicious_words_hindi',
       'malicious_words_bengali', 'malicious_words_English', 'hindi_prompt',
       'telugu_prompt', 'marathi_prompt', 'bengali_prompt', 'English_prompt','assamese', 'telugu','marathi', 'bengali'
])
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1668 entries, 0 to 1667
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   num           1668 non-null   int64
#  1   English       1668 non-null   str
#  2   category      1668 non-null   str
#  3   sub_category  1668 non-null   str
#  4   hindi         1668 non-null   str
# dtypes: int64(1), str(4)
# memory usage: 65.3 KB

# %%
df.to_csv("jailbreak_just_question.csv", index=False)

# %%
import pandas as pd
data = pd.read_csv("initial_malicious_final.csv")
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1668 entries, 0 to 1667
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   num                        1668 non-null   int64
#  1   question                   1668 non-null   str
#  2   category                   1668 non-null   str
#  3   sub_category               1668 non-null   str
#  4   assamese                   1668 non-null   str
#  5   telegu                     1668 non-null   str
#  6   marathi                    1668 non-null   str
#  7   hindi                      1668 non-null   str
#  8   bengali                    1668 non-null   str
#  9   intital_malicious_english  1668 non-null   str
#  10  intital_malicious_hindi    1668 non-null   str
#  11  intital_malicious_marathi  1668 non-null   str
#  12  intital_malicious_bengali  1668 non-null   str
#  13  intital_malicious_telugu   1668 non-null   str
# dtypes: int64(1), str(13)
# ...

# %%
data.columns
# Out:
# Index(['num', 'question', 'category', 'sub_category', 'assamese', 'telegu',
#        'marathi', 'hindi', 'bengali', 'intital_malicious_english',
#        'intital_malicious_hindi', 'intital_malicious_marathi',
#        'intital_malicious_bengali', 'intital_malicious_telugu'],
#       dtype='str')
